# %% [markdown]
# ## Progress Report 1
#
# This notebook displays stats on a limited set of twitter data in the form of JSON files. I clean the dataset and place relevant entries into a pandas DataFrame. All data is taken from ArchiveTeam's [ongoing twitter stream](https://archive.org/search.php?query=twitterstream&sort=-publicdate&page=2) under CC0.

# %% [markdown]
# ### Set Up
#
# This portion of code loads all neccessary libraries and formatting things like pretty print or the interactive shell, which lets me print multiple outputs per cell.

# %%
# Libraries
import tweepy
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
import re
from pandas.io.json import json_normalize

# %%
# Formatting
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %pprint
# Out:
# Pretty printing has been turned OFF

# %%
# Creating keys and auth
consumerKey = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'
consumerSecret = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'
access_token = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'
access_secret = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'

auth = tweepy.OAuthHandler(consumer_key=consumerKey, 
    consumer_secret=consumerSecret)

api = tweepy.API(auth)

# %% [markdown]
# ### Importing Data
#
# This section imports the relevant data. This data is from 2011 around September.

# %%
# lists to store file snippets
d = [] # dir snippet
fn = [] # full file name snippets
i = 0 # iter

# populates the list with directory names
for root, dirs, files in os.walk(r'D:\Documents\Classes\Spring2020\ling1340\Twitter-Positivity-Analysis\data\27'):
    for filename in dirs:
        d.append(filename)

# %%
d
# Out:
# ['19', '20', '21', '22', '23']

# %% [markdown]
# These numerical values are the subfolders of my data file that are holding the JSON files.

# %%
# This loop cycles through each directory (appending it to the file name) and populates the fn array with the filenames  
while True:
    fnd = r'D:\Documents\Classes\Spring2020\ling1340\Twitter-Positivity-Analysis\data\27' + "\\" + d[i]
    for root, dirs, files in os.walk(fnd):
        for filename in files:
            fn.append(d[i] + "\\" + filename) 
            if "bz2" in filename is not True: #there are zip files present in the folder, I want to remove them
                fn.remove(d[i] + "\\" + filename)
    if i >= len(d)-1:
        break
    i = i+1

# %%
fn[:10]
# Out:
# ['19\\48.json', '20\\35.json', '20\\36.json', '20\\37.json', '20\\38.json', '20\\39.json', '20\\40.json', '20\\41.json', '20\\42.json', '20\\43.json']

# %% [markdown]
# Building the fn array to have the directory+filename combo will make it easier to loop through and read all the files later.

# %% [markdown]
# ### Cleaning Data
#
# This section strips the data of extraneous tags and emoticons so that it is easier to tokenize later.

# %%
emoticons_str = r"""
    (?:
        [:=;] 
        [oO\-]? 
        [D\)\]\(\]/\\OpP] 
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)

# %%
# methods to clean text
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

# %% [markdown]
# ### Organizing Data
#
# This section places the data into DataFrames for further analysis. It also trims those DF's to only include relevant information such as text body, date, and language.

# %%
i = 0 # iter
df = pd.DataFrame() # empty dataframe to be appended to

# using the fn array we created here
while True:
    file = r'D:\Documents\Classes\Spring2020\ling1340\Twitter-Positivity-Analysis\data\27' + "\\" + fn[i]
    with open(file, 'r') as f:
        for line in f:
            tweet = json.loads(line) # loads each chunk of json code, which is a tweet
            df = df.append(json_normalize(tweet), sort=False, ignore_index=True) # normalizes the previous tweet 
                                                                                 # into a data frame and appends that to df
    if i > 3: # len(fn)-1: <-- this is what I would use for the full corpus, but I have limited it.
        break
    i = i + 1

# %% [markdown]
# I have only parsed through a sample of the total data because the full amount takes too long to parse during each run.
#
# Here is the unedited DataFrame:

# %%
df
len(df)
# Out:
#      in_reply_to_status_id                                               text  \
# 0                     None  @firawidya iya fir,hihi. Rencananya awal bulan...
# 1                     None   voo sair aki sem maldade, to com mt sono ; #fato
# 2                     None  RT @TheNoteboook: If he loves you, he'll care ...
# 3                     None                    Ombbb @ddlavato singing on abc!
# 4                     None  RT @aniserra: Nunca voy a entender como sabe e...
# ...                    ...                                                ...
# 3691    118877014584328193  @Agosbonelli a full!!! Después empiezan las ve...
# 3692    118876461015900162  @hay_ross ahaha, so am I, but we have our reas...
# 3693    118875695173734400  @densukefukusima つまり、プロローグを消し、回想シーンを冒頭にすることで一工...
# 3694                  None  «@Socialite_Trina ♪ Rolex/ More sex/good weed/...
# 3695                  None  RT @AlbertoCiurana: La confianza se gana. La d...
#
#      in_reply_to_screen_name  truncated  retweeted in_reply_to_status_id_str  \
# 0                  firawidya      False      False                      None
# 1                       None      False      False                      None
# 2                       None       True      False                      None
# 3                       None      False      False                      None
# 4                       None      False      False                      None
# ...                      ...        ...        ...                       ...
# 3691             Agosbonelli      False      False        118877014584328193
# 3692                hay_ross      False      False        118876461015900162
# 3693         densukefukusima      False      False        118875695173734400
# 3694                    None      False      False                      None
# 3695                    None      False      False                      None
#
#                                                  source  \
# 0     <a href="http://ubersocial.com" rel="nofollow"...
# 1                                                   web
# 2     <a href="http://twitter.com/#!/download/iphone...
# 3     <a href="http://twitter.com/devices" rel="nofo...
# 4                                                   web
# ...                                                 ...
# 3691  <a href="http://blackberry.com/twitter" rel="n...
# 3692  <a href="http://twitter.com/download/android" ...
# 3693                                                web
# 3694  <a href="http://levelupstudio.com" rel="nofoll...
# 3695  <a href="http://twitter.com/#!/download/iphone...
#
#                           created_at in_reply_to_user_id_str   geo  ...  \
# 0     Wed Sep 28 01:48:17 +0000 2011                60311908  None  ...
# 1     Wed Sep 28 01:48:17 +0000 2011                    None  None  ...
# 2     Wed Sep 28 01:48:17 +0000 2011                    None  None  ...
# 3     Wed Sep 28 01:48:17 +0000 2011                    None  None  ...
# 4     Wed Sep 28 01:48:15 +0000 2011                    None  None  ...
# ...                              ...                     ...   ...  ...
# 3691  Wed Sep 28 02:38:59 +0000 2011               255577123  None  ...
# 3692  Wed Sep 28 02:38:59 +0000 2011               325945966  None  ...
# 3693  Wed Sep 28 02:38:59 +0000 2011                87141240  None  ...
# 3694  Wed Sep 28 02:38:59 +0000 2011                    None  None  ...
# 3695  Wed Sep 28 02:38:59 +0000 2011                    None  None  ...
#
#      geo.type geo.coordinates coordinates.type coordinates.coordinates  \
# 0         NaN             NaN              NaN                     NaN
# 1         NaN             NaN              NaN                     NaN
# 2         NaN             NaN              NaN                     NaN
# 3         NaN             NaN              NaN                     NaN
# 4         NaN             NaN              NaN                     NaN
# ...       ...             ...              ...                     ...
# 3691      NaN             NaN              NaN                     NaN
# 3692      NaN             NaN              NaN                     NaN
# 3693      NaN             NaN              NaN                     NaN
# 3694      NaN             NaN              NaN                     NaN
# 3695      NaN             NaN              NaN                     NaN
#
#      place.bounding_box retweeted_status.geo.type  \
# 0                   NaN                       NaN
# 1                   NaN                       NaN
# 2                   NaN                       NaN
# 3                   NaN                       NaN
# 4                   NaN                       NaN
# ...                 ...                       ...
# 3691                NaN                       NaN
# 3692                NaN                       NaN
# 3693                NaN                       NaN
# 3694                NaN                       NaN
# 3695                NaN                       NaN
#
#       retweeted_status.geo.coordinates  retweeted_status.coordinates.type  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ...                                ...                                ...
# 3691                               NaN                                NaN
# 3692                               NaN                                NaN
# 3693                               NaN                                NaN
# 3694                               NaN                                NaN
# 3695                               NaN                                NaN
#
#      retweeted_status.coordinates.coordinates retweeted_status.entities.media
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
# ...                                       ...                             ...
# 3691                                      NaN                             NaN
# 3692                                      NaN                             NaN
# 3693                                      NaN                             NaN
# 3694                                      NaN                             NaN
# 3695                                      NaN                             NaN
#
# [3696 rows x 161 columns]
# 3696

# %% [markdown]
# I'm happy to see replies and interactions with other people, because I think that kind of data will speak to how people treated each other online (which can sometimes be where nastiness comes through), but I can see some problems.
#
# As you can see there is a lot of extraneous information represented here. For the sake of my project, which is doing a diachronic sentiment analysis on the content of tweets, the bare bones of what I need to look at is text and date.

# %%
df = df[['text','user.lang', 'created_at']]
df
len(df)
df['user.lang'].value_counts()
# Out:
#                                                    text user.lang  \
# 0     @firawidya iya fir,hihi. Rencananya awal bulan...        en
# 1      voo sair aki sem maldade, to com mt sono ; #fato        pt
# 2     RT @TheNoteboook: If he loves you, he'll care ...        en
# 3                       Ombbb @ddlavato singing on abc!        en
# 4     RT @aniserra: Nunca voy a entender como sabe e...        es
# ...                                                 ...       ...
# 3691  @Agosbonelli a full!!! Después empiezan las ve...        es
# 3692  @hay_ross ahaha, so am I, but we have our reas...        en
# 3693  @densukefukusima つまり、プロローグを消し、回想シーンを冒頭にすることで一工...        ja
# 3694  «@Socialite_Trina ♪ Rolex/ More sex/good weed/...        en
# 3695  RT @AlbertoCiurana: La confianza se gana. La d...        en
#
#                           created_at
# 0     Wed Sep 28 01:48:17 +0000 2011
# 1     Wed Sep 28 01:48:17 +0000 2011
# 2     Wed Sep 28 01:48:17 +0000 2011
# 3     Wed Sep 28 01:48:17 +0000 2011
# 4     Wed Sep 28 01:48:15 +0000 2011
# ...                              ...
# 3691  Wed Sep 28 02:38:59 +0000 2011
# 3692  Wed Sep 28 02:38:59 +0000 2011
# 3693  Wed Sep 28 02:38:59 +0000 2011
# 3694  Wed Sep 28 02:38:59 +0000 2011
# 3695  Wed Sep 28 02:38:59 +0000 2011
#
# [3696 rows x 3 columns]
# 3696
# en       2532
# es        512
# ja        303
# pt        302
# ko         28
# id          9
# fr          5
# ru          2
# de          1
# zh-cn       1
# nl          1
# Name: user.lang, dtype: int64

# %% [markdown]
# Now the data is restricted to 3 columns. I also flashed the counts of the langauges present.
#
# Next, I tried to restrict the language to English, or "en"...

# %%
df[df['user.lang'] == 'en']
len(df[df['user.lang'] == 'en'])
# Out:
#                                                    text user.lang  \
# 0     @firawidya iya fir,hihi. Rencananya awal bulan...        en
# 2     RT @TheNoteboook: If he loves you, he'll care ...        en
# 3                       Ombbb @ddlavato singing on abc!        en
# 6     Não reclamo da vida. É bem provável q ela me p...        en
# 7     No. Don't tell me my flaws. I clearly know the...        en
# ...                                                 ...       ...
# 3689  Gimana cara megangnya? :D RT @bangsaaat: bener...        en
# 3690  @SmokedOutEricaa awww, Im sorry to hear that b...        en
# 3692  @hay_ross ahaha, so am I, but we have our reas...        en
# 3694  «@Socialite_Trina ♪ Rolex/ More sex/good weed/...        en
# 3695  RT @AlbertoCiurana: La confianza se gana. La d...        en
#
#                           created_at
# 0     Wed Sep 28 01:48:17 +0000 2011
# 2     Wed Sep 28 01:48:17 +0000 2011
# 3     Wed Sep 28 01:48:17 +0000 2011
# 6     Wed Sep 28 01:48:17 +0000 2011
# 7     Wed Sep 28 01:48:18 +0000 2011
# ...                              ...
# 3689  Wed Sep 28 02:38:59 +0000 2011
# 3690  Wed Sep 28 02:38:59 +0000 2011
# 3692  Wed Sep 28 02:38:59 +0000 2011
# 3694  Wed Sep 28 02:38:59 +0000 2011
# 3695  Wed Sep 28 02:38:59 +0000 2011
#
# [2532 rows x 3 columns]
# 2532

# %% [markdown]
# However, as you can see there are still some languages other than English present (specifically entries 1 and 6). This is because the "languages" tag referred to *user* language, not the language of the tweet.
#
# That leads me to...
#
# ### Future Plans
#
# I plan to use a language identification library to see if I can figure out the language in a tweet and filter them out that way.
#
# Additionally, I want to convert the time data into something more simple, like maybe just the year.
